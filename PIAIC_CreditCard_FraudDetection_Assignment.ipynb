# %% [markdown]
# <a href="https://colab.research.google.com/github/engrarshad/piaic_q2_DeeplearningAssignmentsSolutions/blob/main/PIAIC_CreditCard_FraudDetection_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Credit Card Fraud Detection::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# ## Identify fraudulent credit card transactions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
import tensorboard
from pylab import rcParams

# %%
# Loading The Data
df = pd.read_csv("/content/drive/MyDrive/AIAssignments/creditcard.csv")
df
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
# # Configuring the Modules
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale = 1.5)
rcParams['figure.figsize'] = 14, 8
Random_Seed = 42

# %%
# Renaming the Columns
df.rename(columns = {"Class": "Fraud"}, inplace = True)

# %%
 df
# Out:
#             Time         V1         V2  ...       V28  Amount  Fraud
# 0            0.0  -1.359807  -0.072781  ... -0.021053  149.62      0
# 1            0.0   1.191857   0.266151  ...  0.014724    2.69      0
# 2            1.0  -1.358354  -1.340163  ... -0.059752  378.66      0
# 3            1.0  -0.966272  -0.185226  ...  0.061458  123.50      0
# 4            2.0  -1.158233   0.877737  ...  0.215153   69.99      0
# ...          ...        ...        ...  ...       ...     ...    ...
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [284807 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
# Checking The Data For Null Values Found
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Fraud     0
# dtype: int64

# %% [markdown]
# No Null Values  Found

# %%
# Checking The Correlations
corr = df.corr()

# generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# figure size
f, ax = plt.subplots(figsize=(10, 10))

# generate diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap='CMRmap_r', vmax=.3, center=0, square=True,
            linewidths=.5, cbar_kws={"shrink": .5})

# %%
labels = ['Valid', 'Fraud']
plt.figure(figsize = (5,5))
count_classes = pd.value_counts(df['Fraud'], sort = True)
count_classes.plot(kind = 'bar', rot=0, color = 'orange', alpha = 0.5)
plt.xticks(range(2), labels)
plt.title("Transaction Class Distribution Graph")
plt.xlabel("Class")
plt.ylabel("Number of Observations")
plt.grid()
plt.show()

# %%
len(df)
# Out:
# 284807

# %% [markdown]
# There are total 284807 number of transactions

# %%
len_fraud = len(df[df.Fraud ==  1])
len_fraud
# Out:
# 492

# %% [markdown]
# Out of 284807 transactions 492 are the fraud transactions

# %%
len_valid = 284807 - 492
len_valid
# Out:
# 284315

# %% [markdown]
# Out of 284807 transactions 284315 are the valid transactions

# %%
perc_fraud = (len_fraud * 100) / len(df)
perc_fraud
# Out:
# 0.1727485630620034

# %% [markdown]
# ### Out of total transactions only **0.17 %** are the fraud transactions. It means that we have highly **Imbalance Dataset**. There is a **huge margin** between the valid transactions and the fraud transactions.

# %%
# Making DataFrames Of Valid And Fraud Transactions To Check Important Stats
Fraud_df = df[df.Fraud == 1]
Valid_df = df[df.Fraud == 0]

# %%
# Checking The Status of Amount used in Fraud Transactions
Fraud_df.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Checking status of Amount used in Valid Transactions
Valid_df.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# So the Amount per transaction by class
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount Per Transaction Graph')

bins = 50

ax1.hist(Fraud_df.Amount, bins = bins, color='red')
ax1.set_title('Fraudulant Transactions')

ax2.hist(Valid_df.Amount, bins = bins, color='green', alpha = 0.5)
ax2.set_title('Valid Transactions')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
# Time vs Amount translactions by class
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time VS Amount Transaction Graph')

ax1.scatter(Fraud_df.Time, Fraud_df.Amount)
ax1.set_title('Fraudulent Transactions')

ax2.scatter(Valid_df.Time,Valid_df.Amount)
ax2.set_title('Valid Transactions')

plt.xlabel('Time (In Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
# Normalizing Data
# We Need To Normalize Two Features: Time And Amount
from sklearn.preprocessing import StandardScaler
df_norm = df
df_norm['Time'] = StandardScaler().fit_transform(df_norm['Time'].values.reshape(-1, 1))
df_norm['Amount'] = StandardScaler().fit_transform(df_norm['Amount'].values.reshape(-1, 1))

# %% [markdown]
# Splitting Dataset Into Training and Testing Data sets

# %%
# Training Data
train_data = df_norm.iloc[:199365,:]
train_data.shape
# Out:
# (199365, 31)

# %%
# Testing Data
test_data = df_norm.iloc[199365:,:]
test_data.shape
# Out:
# (85442, 31)

# %%
train_data
# Out:
#             Time        V1        V2  ...       V28    Amount  Fraud
# 0      -1.996583 -1.359807 -0.072781  ... -0.021053  0.244964      0
# 1      -1.996583  1.191857  0.266151  ...  0.014724 -0.342475      0
# 2      -1.996562 -1.358354 -1.340163  ... -0.059752  1.160686      0
# 3      -1.996562 -0.966272 -0.185226  ...  0.061458  0.140534      0
# 4      -1.996541 -1.158233  0.877737  ...  0.215153 -0.073403      0
# ...          ...       ...       ...  ...       ...       ...    ...
# 199360  0.802584  1.921305  0.395242  ... -0.025723 -0.191467      0
# 199361  0.802584 -0.638489  0.057029  ...  0.100244 -0.265271      0
# 199362  0.802605 -1.383590 -5.632354  ...  0.196356  6.625030      0
# 199363  0.802605 -1.590313  1.185834  ... -0.126385 -0.192147      0
# 199364  0.802626 -1.504565 -1.047164  ... -0.127378  0.120864      0
#
# [199365 rows x 31 columns]

# %%
test_data
# Out:
#             Time         V1         V2  ...       V28    Amount  Fraud
# 199365  0.802626   2.152590  -0.900447  ... -0.044354 -0.129536      0
# 199366  0.802626   1.811278   0.224393  ... -0.022693 -0.350071      0
# 199367  0.802626  -1.524832  -0.544095  ... -0.377957 -0.229689      0
# 199368  0.802647   0.099135   0.873164  ...  0.071553 -0.346113      0
# 199369  0.802647   2.005556  -0.146704  ... -0.069642 -0.331760      0
# ...          ...        ...        ...  ...       ...       ...    ...
# 284802  1.641931 -11.881118  10.071785  ...  0.823731 -0.350151      0
# 284803  1.641952  -0.732789  -0.055080  ... -0.053527 -0.254117      0
# 284804  1.641974   1.919565  -0.301254  ... -0.026561 -0.081839      0
# 284805  1.641974  -0.240440   0.530483  ...  0.104533 -0.313249      0
# 284806  1.642058  -0.533413  -0.189733  ...  0.013649  0.514355      0
#
# [85442 rows x 31 columns]

# %%
# Shuffling Training And Testing Data
train_data = train_data.sample(frac=1)
train_data.head()
# Out:
#             Time        V1        V2  ...       V28    Amount  Fraud
# 141565 -0.219568 -1.476492  1.599154  ...  0.102919 -0.337237      0
# 168435  0.514006 -1.597773 -1.870125  ... -0.341461  0.458182      0
# 124353 -0.369564 -0.521702  1.318908  ...  0.315726 -0.117342      0
# 172951  0.557827  1.424804 -2.579386  ...  0.007862  1.796981      0
# 85752  -0.713629 -1.276943 -0.488366  ... -0.020182 -0.277266      0
#
# [5 rows x 31 columns]

# %%
test_data = test_data.sample(frac = 1)
test_data.head()
# Out:
#             Time        V1        V2  ...       V28    Amount  Fraud
# 269881  1.453063 -0.573154  1.074932  ...  0.279518 -0.289180      0
# 228211  1.065323 -1.073514  1.013085  ...  0.022223 -0.110865      0
# 268891  1.444998  2.060955 -0.087013  ... -0.060897 -0.345313      0
# 280329  1.571872  1.545264 -1.809249  ... -0.018150  0.573647      0
# 213972  0.940429 -2.970413 -4.035070  ...  0.042353  0.402449      0
#
# [5 rows x 31 columns]

# %%
# Droping Labels From Training And Testing Data
train_labels = train_data.pop('Fraud')
# train_labels = train_labels.values
test_labels = test_data.pop('Fraud')
# test_labels = test_labels.values

# %%
train_labels
# Out:
# 141565    0
# 168435    0
# 124353    0
# 172951    0
# 85752     0
#          ..
# 107007    0
# 94978     0
# 122933    0
# 173634    0
# 168505    0
# Name: Fraud, Length: 199365, dtype: int64

# %%
test_labels
# Out:
# 269881    0
# 228211    0
# 268891    0
# 280329    0
# 213972    0
#          ..
# 252036    0
# 247718    0
# 219532    0
# 225065    0
# 242350    0
# Name: Fraud, Length: 85442, dtype: int64

# %%
# Building Base Model
model = Sequential()
model.add(Dense(10, activation = 'relu', input_shape = [len(train_data.keys())]))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(6, activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                310
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 459
# Trainable params: 459
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard
checkpointer = ModelCheckpoint(filepath = 'CreditCardFraudDetectionModel.h5', verbose = 0, save_best_only = True)
tensorboard = TensorBoard(log_dir = './logs', histogram_freq = 0, write_graph = True, write_images = True)

# %%
history = model.fit(train_data, train_labels, epochs = 100, batch_size = 32, shuffle=True, validation_split=0.2, verbose = 1, callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 4985/4985 [==============================] - 8s 1ms/step - loss: 0.0522 - accuracy: 0.9979 - val_loss: 0.0035 - val_accuracy: 0.9994
# Epoch 2/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0032 - val_accuracy: 0.9994
# Epoch 3/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0030 - val_accuracy: 0.9995
# Epoch 4/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0038 - val_accuracy: 0.9993
# Epoch 5/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0029 - val_accuracy: 0.9994
# Epoch 6/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0035 - val_accuracy: 0.9992
# Epoch 7/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0029 - val_accuracy: 0.9994
# Epoch 8/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0033 - val_accuracy: 0.9993
# Epoch 9/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0032 - val_accuracy: 0.9995
# Epoch 10/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0034 - val_accuracy: 0.9994
# Epoch 11/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0029 - val_accuracy: 0.9995
# Epoch 12/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9995
# Epoch 13/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0036 - val_accuracy: 0.9995
# Epoch 14/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0036 - val_accuracy: 0.9994
# Epoch 15/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0033 - val_accuracy: 0.9995
# Epoch 16/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 0.9994
# Epoch 17/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0032 - val_accuracy: 0.9995
# Epoch 18/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9995
# Epoch 19/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9994
# Epoch 20/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0033 - val_accuracy: 0.9994
# Epoch 21/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0034 - val_accuracy: 0.9994
# Epoch 22/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0034 - val_accuracy: 0.9994
# Epoch 23/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9995
# Epoch 24/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0034 - val_accuracy: 0.9995
# Epoch 25/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0035 - val_accuracy: 0.9995
# Epoch 26/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9994
# Epoch 27/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0035 - val_accuracy: 0.9995
# Epoch 28/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0038 - val_accuracy: 0.9994
# Epoch 29/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0041 - val_accuracy: 0.9994
# Epoch 30/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0036 - val_accuracy: 0.9995
# Epoch 31/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0039 - val_accuracy: 0.9995
# Epoch 32/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0040 - val_accuracy: 0.9993
# Epoch 33/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0039 - val_accuracy: 0.9995
# Epoch 34/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0043 - val_accuracy: 0.9994
# Epoch 35/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0040 - val_accuracy: 0.9994
# Epoch 36/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0041 - val_accuracy: 0.9995
# Epoch 37/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0046 - val_accuracy: 0.9993
# Epoch 38/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0039 - val_accuracy: 0.9994
# Epoch 39/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0040 - val_accuracy: 0.9995
# Epoch 40/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0040 - val_accuracy: 0.9995
# Epoch 41/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0044 - val_accuracy: 0.9995
# Epoch 42/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0046 - val_accuracy: 0.9995
# Epoch 43/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0048 - val_accuracy: 0.9995
# Epoch 44/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0045 - val_accuracy: 0.9995
# Epoch 45/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0049 - val_accuracy: 0.9995
# Epoch 46/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0046 - val_accuracy: 0.9996
# Epoch 47/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0050 - val_accuracy: 0.9995
# Epoch 48/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0050 - val_accuracy: 0.9995
# Epoch 49/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0049 - val_accuracy: 0.9996
# Epoch 50/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0059 - val_accuracy: 0.9995
# Epoch 51/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0049 - val_accuracy: 0.9995
# Epoch 52/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0047 - val_accuracy: 0.9994
# Epoch 53/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0053 - val_accuracy: 0.9994
# Epoch 54/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0047 - val_accuracy: 0.9996
# Epoch 55/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0057 - val_accuracy: 0.9996
# Epoch 56/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0052 - val_accuracy: 0.9996
# Epoch 57/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0054 - val_accuracy: 0.9995
# Epoch 58/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0055 - val_accuracy: 0.9996
# Epoch 59/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0061 - val_accuracy: 0.9996
# Epoch 60/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0062 - val_accuracy: 0.9995
# Epoch 61/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0062 - val_accuracy: 0.9995
# Epoch 62/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0062 - val_accuracy: 0.9996
# Epoch 63/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0062 - val_accuracy: 0.9996
# Epoch 64/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0059 - val_accuracy: 0.9996
# Epoch 65/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0060 - val_accuracy: 0.9995
# Epoch 66/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0060 - val_accuracy: 0.9996
# Epoch 67/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0071 - val_accuracy: 0.9995
# Epoch 68/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0061 - val_accuracy: 0.9995
# Epoch 69/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0061 - val_accuracy: 0.9995
# Epoch 70/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0068 - val_accuracy: 0.9995
# Epoch 71/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0078 - val_accuracy: 0.9995
# Epoch 72/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0066 - val_accuracy: 0.9995
# Epoch 73/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0061 - val_accuracy: 0.9994
# Epoch 74/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0073 - val_accuracy: 0.9994
# Epoch 75/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0064 - val_accuracy: 0.9995
# Epoch 76/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0070 - val_accuracy: 0.9996
# Epoch 77/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0078 - val_accuracy: 0.9994
# Epoch 78/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0066 - val_accuracy: 0.9995
# Epoch 79/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0077 - val_accuracy: 0.9995
# Epoch 80/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0075 - val_accuracy: 0.9995
# Epoch 81/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0070 - val_accuracy: 0.9996
# Epoch 82/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0071 - val_accuracy: 0.9996
# Epoch 83/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0071 - val_accuracy: 0.9995
# Epoch 84/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0074 - val_accuracy: 0.9995
# Epoch 85/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0064 - val_accuracy: 0.9994
# Epoch 86/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0072 - val_accuracy: 0.9995
# Epoch 87/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0080 - val_accuracy: 0.9994
# Epoch 88/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0069 - val_accuracy: 0.9995
# Epoch 89/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0075 - val_accuracy: 0.9996
# Epoch 90/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 9.4988e-04 - accuracy: 0.9997 - val_loss: 0.0067 - val_accuracy: 0.9994
# Epoch 91/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0079 - val_accuracy: 0.9994
# Epoch 92/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0081 - val_accuracy: 0.9996
# Epoch 93/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0078 - val_accuracy: 0.9995
# Epoch 94/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0073 - val_accuracy: 0.9995
# Epoch 95/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0076 - val_accuracy: 0.9996
# Epoch 96/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0078 - val_accuracy: 0.9993
# Epoch 97/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0076 - val_accuracy: 0.9994
# Epoch 98/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0082 - val_accuracy: 0.9995
# Epoch 99/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0091 - val_accuracy: 0.9995
# Epoch 100/100
# 4985/4985 [==============================] - 7s 1ms/step - loss: 8.6591e-04 - accuracy: 0.9997 - val_loss: 0.0084 - val_accuracy: 0.9995

# %%
# Storing History In A Data Frame
history_df = pd.DataFrame(history)
history_df.tail()
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 95  0.001237  0.999724  0.007756      0.999323
# 96  0.001191  0.999649  0.007621      0.999398
# 97  0.001246  0.999630  0.008211      0.999549
# 98  0.001137  0.999680  0.009073      0.999498
# 99  0.001287  0.999636  0.008401      0.999473

# %%
# Plotting Loss and Accuracy
plt.plot(history_df['loss'])
plt.plot(history_df['accuracy'])
plt.plot(history_df['val_loss'])
plt.plot(history_df['val_accuracy'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training Loss', 'Training Accuracy', 'Validation Loss', 'Validation Accuracy'], loc='upper right');

# %%
# Making Predictions On Test Data
predictions = model.predict(test_data)
predictions = predictions.flatten()

# %%
predictions
# Out:
# array([3.1129284e-36, 5.6094049e-09, 1.3404509e-13, ..., 1.1030693e-27,
#        9.7148710e-17, 1.2072855e-21], dtype=float32)

# %%
testing = model.evaluate(test_data, test_labels)
# Out:
# 2671/2671 [==============================] - 2s 867us/step - loss: 0.0088 - accuracy: 0.9995

# %%
print(f"Test Loss: {testing[0]}")
print(f"Test Accuracy: {testing[1]}")
# Out:
# Test Loss: 0.008787914179265499
# Test Accuracy: 0.9994967579841614
